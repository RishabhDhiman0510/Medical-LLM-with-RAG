# %%
# Cell 1: Load your RAG system
# %run medical-rag-final.py
# Out:
# WARNING:tensorflow:From C:\Users\risha\AppData\Local\Programs\Python\Python312\Lib\site-packages\tf_keras\src\losses.py:2976: The name tf.losses.sparse_softmax_cross_entropy is deprecated. Please use tf.compat.v1.losses.sparse_softmax_cross_entropy instead.
#
#
# **********************************************************************
# INITIALIZING OPTIMIZED MEDICAL RAG SYSTEM
# **********************************************************************
#
# ...
# 🚀 OPTIMIZED MEDICAL RAG - CONVERSATIONAL WITH LEARNING
# ...
# ✅ All fixes applied:
#    • Embedding: all-MiniLM-L6-v2
#    • Min Similarity: 0.35
#    • Top-K: 15, Rerank: 8
#    • Temperature: 0.5
#    • Chunk Size: 512
# ...
#
# 📦 Loading model...
#    Base model: FreedomIntelligence/Apollo-2B
# The `load_in_4bit` and `load_in_8bit` arguments are deprecated and will be removed in the future versions. Please, pass a `BitsAndBytesConfig` object in `quantization_config` argument instead.
# ...

# %%
# Cell 2
from comprehensive_testing_suite import ComprehensiveTestingSystem

# Or load everything
# %run comprehensive_testing_suite.py
# Out:
# ✅ All imports successful
# ✅ All imports successful
# Testing suite loaded!
# To run tests in Jupyter:
#   tester = ComprehensiveTestingSystem(rag_system)
#   df_results, summary = tester.run_full_evaluation()

# %%
# Cell 3
tester = ComprehensiveTestingSystem(rag_system)
df_results, summary = tester.run_full_evaluation()
# Out:
# 📊 Initializing comprehensive metrics...
# ⚠️ Medical NER not available (optional)
# ⚠️ BERTScore not available (will use semantic similarity)
# ✅ Testing system initialized
#    Results directory: test_results
#
# 📊 Loading test dataset...
# ✅ Loaded 44 medical questions
#
# ...
# TESTING MEDICAL RAG SYSTEM
# ...
# Total questions to test: 44
#
# [ 1/44] Testing: What are the symptoms of acute myocardial infarction?... ✓ (BLEU: 0.02)
# [ 2/44] Testing: How is hypertension diagnosed and classified?... ✓ (BLEU: 0.01)
# [ 3/44] Testing: What is the mechanism of ACE inhibitors?... ✓ (BLEU: 0.01)
# [ 4/44] Testing: What are risk factors for heart disease?... ✓ (BLEU: 0.01)
# [ 5/44] Testing: What is atrial fibrillation and its complications?... ✓ (BLEU: 0.00)
# [ 6/44] Testing: What are the diagnostic criteria for diabetes mellitus type ... ✓ (BLEU: 0.00)
# [ 7/44] Testing: What is the HbA1c target for diabetes management?... ✓ (BLEU: 0.00)
# ...

# %%
from interactive_chatbot import create_interactive_chatbot
chatbot = create_interactive_chatbot(rag_system)
chatbot.show()
# Out:
# ✅ Initializing Interactive Medical Chatbot...
# ✅ UI Created. Display with: chatbot.show()
# ...
